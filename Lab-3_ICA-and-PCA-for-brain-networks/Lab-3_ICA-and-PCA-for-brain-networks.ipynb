# %%
# !pip install brainspace nilearn brainstat nibabel
# Out:
# Requirement already satisfied: brainspace in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (0.1.20)
# Requirement already satisfied: nilearn in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (0.12.1)
# Requirement already satisfied: brainstat in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (0.4.2)
# Requirement already satisfied: nibabel in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (5.3.2)
# Requirement already satisfied: numpy>=1.11.0 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from brainspace) (1.26.4)
# Requirement already satisfied: scipy>=0.17.0 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from brainspace) (1.15.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from brainspace) (1.7.2)
# Requirement already satisfied: matplotlib>=2.0.0 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from brainspace) (3.10.3)
# Requirement already satisfied: vtk<9.3.2,>=8.1.0 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from brainspace) (9.3.1)
# Requirement already satisfied: pillow in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from brainspace) (9.2.0)
# Requirement already satisfied: pandas in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from brainspace) (2.3.3)
# Requirement already satisfied: joblib>=1.2.0 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from nilearn) (1.4.2)
# Requirement already satisfied: lxml in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from nilearn) (5.3.1)
# Requirement already satisfied: packaging in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from nilearn) (23.1)
# Requirement already satisfied: requests>=2.25.0 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from nilearn) (2.31.0)
# Requirement already satisfied: abagen>=0.1 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from brainstat) (0.1.3)
# Requirement already satisfied: h5py in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from brainstat) (3.11.0)
# Requirement already satisfied: netneurotools in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from brainstat) (0.3.0)
# Requirement already satisfied: neurosynth in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from brainstat) (0.3.8)
# Requirement already satisfied: nimare in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from brainstat) (0.6.1)
# Requirement already satisfied: templateflow in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from brainstat) (25.1.1)
# Requirement already satisfied: trimesh in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from brainstat) (4.9.0)
# Requirement already satisfied: typing-extensions>=4.6 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from nibabel) (4.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from matplotlib>=2.0.0->brainspace) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from matplotlib>=2.0.0->brainspace) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from matplotlib>=2.0.0->brainspace) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from matplotlib>=2.0.0->brainspace) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from matplotlib>=2.0.0->brainspace) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from matplotlib>=2.0.0->brainspace) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from pandas->brainspace) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from pandas->brainspace) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->brainspace) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from requests>=2.25.0->nilearn) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from requests>=2.25.0->nilearn) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from requests>=2.25.0->nilearn) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from requests>=2.25.0->nilearn) (2025.4.26)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from scikit-learn>=0.20.0->brainspace) (3.6.0)
# Requirement already satisfied: bctpy in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from netneurotools->brainstat) (0.6.1)
# Requirement already satisfied: tqdm in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from netneurotools->brainstat) (4.65.0)
# Requirement already satisfied: ply in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from neurosynth->brainstat) (3.11)
# Requirement already satisfied: biopython in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from neurosynth->brainstat) (1.85)
# Requirement already satisfied: cognitiveatlas>=0.1.11 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from nimare->brainstat) (0.1.11)
# Requirement already satisfied: fuzzywuzzy in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from nimare->brainstat) (0.18.0)
# Requirement already satisfied: jinja2 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from nimare->brainstat) (3.1.6)
# Requirement already satisfied: numba>=0.57.0 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from nimare->brainstat) (0.62.1)
# Requirement already satisfied: patsy in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from nimare->brainstat) (1.0.2)
# Requirement already satisfied: plotly in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from nimare->brainstat) (6.3.1)
# Requirement already satisfied: pymare>=0.0.8 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from nimare->brainstat) (0.0.10)
# Requirement already satisfied: pyyaml in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from nimare->brainstat) (6.0.3)
# Requirement already satisfied: ridgeplot in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from nimare->brainstat) (0.5.0)
# Requirement already satisfied: sparse>=0.13.0 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from nimare->brainstat) (0.17.0)
# Requirement already satisfied: statsmodels!=0.13.2 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from nimare->brainstat) (0.14.5)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from numba>=0.57.0->nimare->brainstat) (0.45.1)
# Requirement already satisfied: sympy in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from pymare>=0.0.8->nimare->brainstat) (1.14.0)
# Requirement already satisfied: wrapt in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from pymare>=0.0.8->nimare->brainstat) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from jinja2->nimare->brainstat) (2.1.5)
# Requirement already satisfied: narwhals>=1.15.1 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from plotly->nimare->brainstat) (2.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from sympy->pymare>=0.0.8->nimare->brainstat) (1.3.0)
# Requirement already satisfied: acres>=0.5.0 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from templateflow->brainstat) (0.5.0)
# Requirement already satisfied: platformdirs>=4.0 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from templateflow->brainstat) (4.5.0)
# Requirement already satisfied: pybids>=0.15.2 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from templateflow->brainstat) (0.21.0)
# Requirement already satisfied: formulaic>=0.3 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from pybids>=0.15.2->templateflow->brainstat) (1.2.1)
# Requirement already satisfied: sqlalchemy>=1.4.31 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from pybids>=0.15.2->templateflow->brainstat) (2.0.44)
# Requirement already satisfied: bids-validator>=1.14.7 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from pybids>=0.15.2->templateflow->brainstat) (1.14.7.post0)
# Requirement already satisfied: num2words>=0.5.10 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from pybids>=0.15.2->templateflow->brainstat) (0.5.14)
# Requirement already satisfied: click>=8.0 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from pybids>=0.15.2->templateflow->brainstat) (8.1.7)
# Requirement already satisfied: universal_pathlib>=0.2.2 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from pybids>=0.15.2->templateflow->brainstat) (0.3.4)
# Requirement already satisfied: frozendict>=2.3 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from pybids>=0.15.2->templateflow->brainstat) (2.4.6)
# Requirement already satisfied: bidsschematools>=0.10 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from bids-validator>=1.14.7->pybids>=0.15.2->templateflow->brainstat) (1.1.0)
# Requirement already satisfied: interface-meta>=1.2.0 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from formulaic>=0.3->pybids>=0.15.2->templateflow->brainstat) (1.3.0)
# Requirement already satisfied: docopt>=0.6.2 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from num2words>=0.5.10->pybids>=0.15.2->templateflow->brainstat) (0.6.2)
# Requirement already satisfied: fsspec>=2024.5.0 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from universal_pathlib>=0.2.2->pybids>=0.15.2->templateflow->brainstat) (2025.9.0)
# Requirement already satisfied: pathlib-abc<0.6.0,>=0.5.1 in /Users/radek.kawa/miniconda3/lib/python3.12/site-packages (from universal_pathlib>=0.2.2->pybids>=0.15.2->templateflow->brainstat) (0.5.2)

# %%
from nilearn import datasets, image
import nilearn.plotting as niplot
from nilearn.decomposition import CanICA
from brainspace.datasets import load_group_fc, load_parcellation, load_conte69
from brainspace.gradient import GradientMaps
from brainspace.utils.parcellation import map_to_labels
from brainspace.plotting import plot_hemispheres
from brainstat.datasets import fetch_yeo_networks_metadata
from brainstat.datasets import fetch_parcellation
from brainstat.datasets import fetch_mask, fetch_template_surface
import matplotlib as plt
import numpy as np
from brainspace.mesh.mesh_io import read_surface
import os
import pandas as pd
import matplotlib.pyplot as plt
import nibabel as nb
from IPython.display import Image
from nilearn.plotting import plot_prob_atlas
from nilearn.image import iter_img
from nilearn.plotting import plot_stat_map, show

# %% [markdown]
# # Lab 3 - ICA and PCA for detecting brain networks
#
# In this lab, we are going to explore the brain dynamics via more "traditional" approaches such as independent component analysis (ICA) and principal component analysis (PCA).
#
# Both approaches are useful to identify the regions that show similar temporal dynamics, in other words, regions that correlate with each other.
#
# More technically, the earlier approach is looking for seperate components that maximize the explained variance in the given signal, whereas the latter approach is looking for one common component that explains the most variance.

# %% [markdown]
# # ICA

# %% [markdown]
# With ICA, we aim to detect the regions that show correlated functional dynamics with eachother. To start with, we are going to download a series of functional images from Nilearn's library. Subjects children changing between 3 and 12 years and are recorded while they are watching a pixar movie (Published [here](https://www.nature.com/articles/s41467-018-03399-2) and available [here](https://nilearn.github.io/stable/modules/generated/nilearn.datasets.fetch_development_fmri.html#footcite-richardson2018). The tutorial is adapted from [here](https://nilearn.github.io/stable/auto_examples/03_connectivity/plot_compare_decomposition.html#sphx-glr-auto-examples-03-connectivity-plot-compare-decomposition-py)).

# %%
# First, change to working directiory to Lab folder
# os.chdir('Lab-3_ICA-and-PCA-for-brain-networks/')

# %%
subjects=15 # How many subjects' data we want to download

rest_dataset = datasets.fetch_development_fmri(n_subjects=subjects)
func_filenames = rest_dataset.func  # list of 4D nifti files for each subject

# print basic information on the dataset
print(f"First functional nifti image (4D) is at: {rest_dataset.func[0]}")
mean=image.mean_img(rest_dataset.func[0])
# Out:
# [fetch_development_fmri] Added README.md to /Users/radek.kawa/nilearn_data
# [fetch_development_fmri] Dataset created in /Users/radek.kawa/nilearn_data/development_fmri
# [fetch_development_fmri] Added README.md to /Users/radek.kawa/nilearn_data/development_fmri
# [fetch_development_fmri] Dataset created in /Users/radek.kawa/nilearn_data/development_fmri/development_fmri
# [fetch_development_fmri] Downloading data from https://osf.io/yr3av/download ...
# [fetch_development_fmri]  ...done. (31 seconds, 0 min)
# [fetch_development_fmri] Dataset found in /Users/radek.kawa/nilearn_data/development_fmri/development_fmri
# [fetch_development_fmri] Downloading data from https://osf.io/download/5c8ff3df4712b400183b7092/ ...
# [fetch_development_fmri]  ...done. (4 seconds, 0 min)
# [fetch_development_fmri] Downloading data from https://osf.io/download/5c8ff3e04712b400193b5bdf/ ...
# [fetch_development_fmri] Downloaded 4587520 of 5642698 bytes (81.3%%,    0.2s remaining)
# [fetch_development_fmri]  ...done. (5 seconds, 0 min)
# [fetch_development_fmri] Downloading data from https://osf.io/download/5c8ff3e14712b400183b7097/ ...
# [fetch_development_fmri]  ...done. (4 seconds, 0 min)
# [fetch_development_fmri] Downloading data from https://osf.io/download/5c8ff3e32286e80018c3e42c/ ...
# [fetch_development_fmri] Downloaded 3383296 of 4946416 bytes (68.4%%,    0.5s remaining)
# [fetch_development_fmri]  ...done. (4 seconds, 0 min)
# [fetch_development_fmri] Downloading data from https://osf.io/download/5c8ff3e4a743a9001760814f/ ...
# [fetch_development_fmri]  ...done. (4 seconds, 0 min)
# [fetch_development_fmri] Downloading data from https://osf.io/download/5c8ff3e54712b400183b70a5/ ...
# [fetch_development_fmri] Downloaded 3416064 of 5875966 bytes (58.1%%,    0.7s remaining)
# [fetch_development_fmri]  ...done. (4 seconds, 0 min)
# [fetch_development_fmri] Downloading data from https://osf.io/download/5c8ff37da743a90018606df1/ ...
# [fetch_development_fmri]  ...done. (2 seconds, 0 min)
# [fetch_development_fmri] Downloading data from https://osf.io/download/5c8ff37c2286e80019c3c102/ ...
# [fetch_development_fmri] Downloaded 4800512 of 6293165 bytes (76.3%%,    0.3s remaining)
# [fetch_development_fmri]  ...done. (3 seconds, 0 min)
# [fetch_development_fmri] Downloading data from https://osf.io/download/5cb4701e3992690018133d4f/ ...
# [fetch_development_fmri]  ...done. (2 seconds, 0 min)
# [fetch_development_fmri] Downloading data from https://osf.io/download/5cb46e6b353c58001b9cb34f/ ...
# [fetch_development_fmri] Downloaded 3031040 of 6136523 bytes (49.4%%,    1.0s remaining)
# [fetch_development_fmri]  ...done. (6 seconds, 0 min)
# [fetch_development_fmri] Downloading data from https://osf.io/download/5c8ff37d4712b400193b5b54/ ...
# [fetch_development_fmri]  ...done. (3 seconds, 0 min)
# [fetch_development_fmri] Downloading data from https://osf.io/download/5c8ff37d4712b400183b7011/ ...
# [fetch_development_fmri] Downloaded 4784128 of 5837641 bytes (82.0%%,    0.2s remaining)
# [fetch_development_fmri]  ...done. (4 seconds, 0 min)
# [fetch_development_fmri] Downloading data from https://osf.io/download/5c8ff37e2286e80016c3c2cb/ ...
# [fetch_development_fmri]  ...done. (3 seconds, 0 min)
# [fetch_development_fmri] Downloading data from https://osf.io/download/5c8ff3832286e80019c3c10f/ ...
# [fetch_development_fmri] Downloaded 3301376 of 6118892 bytes (54.0%%,    0.9s remaining)
# [fetch_development_fmri]  ...done. (4 seconds, 0 min)
# [fetch_development_fmri] Downloading data from https://osf.io/download/5c8ff3822286e80018c3e37b/ ...
# [fetch_development_fmri]  ...done. (3 seconds, 0 min)
# [fetch_development_fmri] Downloading data from https://osf.io/download/5c8ff382a743a90018606df8/ ...
# [fetch_development_fmri] Downloaded 3448832 of 6453693 bytes (53.4%%,    0.9s remaining)
# [fetch_development_fmri]  ...done. (3 seconds, 0 min)
# [fetch_development_fmri] Downloading data from https://osf.io/download/5c8ff3814712b4001a3b5561/ ...
# [fetch_development_fmri]  ...done. (2 seconds, 0 min)
# [fetch_development_fmri] Downloading data from https://osf.io/download/5c8ff3832286e80016c3c2d1/ ...
# [fetch_development_fmri] Downloaded 3440640 of 6176491 bytes (55.7%%,    0.8s remaining)
# [fetch_development_fmri]  ...done. (10 seconds, 0 min)
# [fetch_development_fmri] Downloading data from https://osf.io/download/5c8ff3842286e80017c419e0/ ...
# [fetch_development_fmri]  ...done. (2 seconds, 0 min)
# [fetch_development_fmri] Downloading data from https://osf.io/download/5c8ff3854712b4001a3b5568/ ...
# [fetch_development_fmri] Downloaded 3301376 of 6225801 bytes (53.0%%,    0.9s remaining)
# [fetch_development_fmri]  ...done. (4 seconds, 0 min)
# [fetch_development_fmri] Downloading data from https://osf.io/download/5cb4702f39926900171090ee/ ...
# [fetch_development_fmri]  ...done. (3 seconds, 0 min)
# [fetch_development_fmri] Downloading data from https://osf.io/download/5cb46e8b353c58001c9abe98/ ...
# [fetch_development_fmri] Downloaded 3399680 of 6232787 bytes (54.5%%,    0.8s remaining)
# [fetch_development_fmri]  ...done. (3 seconds, 0 min)
# [fetch_development_fmri] Downloading data from https://osf.io/download/5c8ff3872286e80017c419ea/ ...
# [fetch_development_fmri]  ...done. (4 seconds, 0 min)
# [fetch_development_fmri] Downloading data from https://osf.io/download/5c8ff3872286e80017c419e9/ ...
# [fetch_development_fmri] Downloaded 1179648 of 7361169 bytes (16.0%%,    5.5s remaining)
# [fetch_development_fmri] Downloaded 6209536 of 7361169 bytes (84.4%%,    0.4s remaining)
# [fetch_development_fmri]  ...done. (6 seconds, 0 min)
# [fetch_development_fmri] Downloading data from https://osf.io/download/5c8ff3884712b400183b7023/ ...
# [fetch_development_fmri]  ...done. (2 seconds, 0 min)
# [fetch_development_fmri] Downloading data from https://osf.io/download/5c8ff3884712b400193b5b5c/ ...
# [fetch_development_fmri] Downloaded 3481600 of 6586819 bytes (52.9%%,    0.9s remaining)
# [fetch_development_fmri]  ...done. (3 seconds, 0 min)
# [fetch_development_fmri] Downloading data from https://osf.io/download/5c8ff389a743a9001660a016/ ...
# [fetch_development_fmri]  ...done. (4 seconds, 0 min)
# [fetch_development_fmri] Downloading data from https://osf.io/download/5c8ff38c2286e80016c3c2da/ ...
# [fetch_development_fmri] Downloaded 1662976 of 6111716 bytes (27.2%%,    2.7s remaining)
# [fetch_development_fmri]  ...done. (4 seconds, 0 min)
# [fetch_development_fmri] Downloading data from https://osf.io/download/5c8ff38ca743a90018606dfe/ ...
# [fetch_development_fmri]  ...done. (2 seconds, 0 min)
# [fetch_development_fmri] Downloading data from https://osf.io/download/5c8ff38ca743a9001760809e/ ...
# [fetch_development_fmri] Downloaded 3022848 of 6067448 bytes (49.8%%,    1.0s remaining)
# [fetch_development_fmri]  ...done. (7 seconds, 0 min)
# First functional nifti image (4D) is at: /Users/radek.kawa/nilearn_data/development_fmri/development_fmri/sub-pixar123_task-pixar_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /var/folders/j8/ycql35hs3415ybxz7vjtcrr40000gn/T/ipykernel_39616/1593005792.py:8: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   mean=image.mean_img(rest_dataset.func[0])

# %% [markdown]
# Let's have a look at a mean image of one subject. Each point on the brain has a time-series with 168 time points. So, each image is a set of time series showing the functional dynamics of that specific point of the brain.

# %%
niplot.plot_epi(mean)
print(image.load_img(rest_dataset.func[0]).shape)
# Out:
# (50, 59, 50, 168)

# %% [markdown]
# # Conducting the ICA
#
# The detailed method is explained [here](https://pubmed.ncbi.nlm.nih.gov/20153834/). In short, this methods create spatial independent component maps for each subject, and then creates group-level maps based on the spatial consistency of those maps. A snapshot of the workflow can be seen below.

# %%
Image(filename='ica_workflow.png')

# %%
# Let's run the model on our data

canica = CanICA(
    n_components=20,
    memory="nilearn_cache",
    memory_level=2,
    verbose=10,
    mask_strategy="whole-brain-template",
    random_state=0,
    standardize="zscore_sample",
)
canica.fit(func_filenames)

# Retrieve the independent components in brain space. Directly
# accessible through attribute `components_img_`.
canica_components_img = canica.components_img_
# components_img is a Nifti Image object, and can be saved to a file with
# the following line:
canica_components_img.to_filename("canica_resting_state.nii.gz")

# Save the component maps seperately
canica_components_img = canica.components_img_
# Out:
# [CanICA.fit] Loading data from [sub-pixar123_task-...,
#          ...
#  sub-pixar012_task-...]
# [CanICA.fit] Computing mask
# [CanICA.fit] Template whole-brain mask computation
# [CanICA.fit] Resamping mask
# [CanICA.fit] Finished fit
# [CanICA.fit] Loading data
# [CanICA.fit] Loading data from Nifti1Image('sub-pixar123_task-...')
# [CanICA.fit] Smoothing images
# [CanICA.fit] Extracting region signals
# [CanICA.fit] Cleaning extracted signals
# [CanICA.fit] Loading data from Nifti1Image('sub-pixar124_task-...')
# [CanICA.fit] Smoothing images
# [CanICA.fit] Extracting region signals
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# [CanICA.fit] Cleaning extracted signals
# [CanICA.fit] Loading data from Nifti1Image('sub-pixar125_task-...')
# [CanICA.fit] Smoothing images
# [CanICA.fit] Extracting region signals
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# [CanICA.fit] Cleaning extracted signals
# [CanICA.fit] Loading data from Nifti1Image('sub-pixar001_task-...')
# [CanICA.fit] Smoothing images
# [CanICA.fit] Extracting region signals
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# [CanICA.fit] Cleaning extracted signals
# [CanICA.fit] Loading data from Nifti1Image('sub-pixar002_task-...')
# [CanICA.fit] Smoothing images
# [CanICA.fit] Extracting region signals
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# [CanICA.fit] Cleaning extracted signals
# [CanICA.fit] Loading data from Nifti1Image('sub-pixar003_task-...')
# [CanICA.fit] Smoothing images
# [CanICA.fit] Extracting region signals
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# [CanICA.fit] Cleaning extracted signals
# [CanICA.fit] Loading data from Nifti1Image('sub-pixar004_task-...')
# [CanICA.fit] Smoothing images
# [CanICA.fit] Extracting region signals
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# [CanICA.fit] Cleaning extracted signals
# [CanICA.fit] Loading data from Nifti1Image('sub-pixar005_task-...')
# [CanICA.fit] Smoothing images
# [CanICA.fit] Extracting region signals
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# [CanICA.fit] Cleaning extracted signals
# [CanICA.fit] Loading data from Nifti1Image('sub-pixar006_task-...')
# [CanICA.fit] Smoothing images
# [CanICA.fit] Extracting region signals
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# [CanICA.fit] Cleaning extracted signals
# [CanICA.fit] Loading data from Nifti1Image('sub-pixar007_task-...')
# [CanICA.fit] Smoothing images
# [CanICA.fit] Extracting region signals
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# [CanICA.fit] Cleaning extracted signals
# [CanICA.fit] Loading data from Nifti1Image('sub-pixar008_task-...')
# [CanICA.fit] Smoothing images
# [CanICA.fit] Extracting region signals
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# [CanICA.fit] Cleaning extracted signals
# [CanICA.fit] Loading data from Nifti1Image('sub-pixar009_task-...')
# [CanICA.fit] Smoothing images
# [CanICA.fit] Extracting region signals
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# [CanICA.fit] Cleaning extracted signals
# [CanICA.fit] Loading data from Nifti1Image('sub-pixar010_task-...')
# [CanICA.fit] Smoothing images
# [CanICA.fit] Extracting region signals
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# [CanICA.fit] Cleaning extracted signals
# [CanICA.fit] Loading data from Nifti1Image('sub-pixar011_task-...')
# [CanICA.fit] Smoothing images
# [CanICA.fit] Extracting region signals
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# [CanICA.fit] Cleaning extracted signals
# [CanICA.fit] Loading data from Nifti1Image('sub-pixar012_task-...')
# [CanICA.fit] Smoothing images
# [CanICA.fit] Extracting region signals
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# [CanICA.fit] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling sklearn.utils.extmath.randomized_svd...
# randomized_svd(array([[ 0.003659, ..., -0.003023],
#        ...,
#        [ 0.012477, ..., -0.003596]]), n_components=20, transpose=True, random_state=0, n_iter=3)
# ___________________________________________________randomized_svd - 3.6s, 0.1min
# [CanICA.fit] Computing image from signals
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[ 0.003886, ..., -0.00295 ],
#        ...,
#        [ 0.005665, ...,  0.001215]]), whiten='arbitrary-variance', fun='cube', random_state=209652396)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:   56.8s
# _________________________________________________________fastica - 56.8s, 0.9min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[ 0.003886, ..., -0.00295 ],
#        ...,
#        [ 0.005665, ...,  0.001215]]), whiten='arbitrary-variance', fun='cube', random_state=398764591)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# _________________________________________________________fastica - 54.8s, 0.9min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[ 0.003886, ..., -0.00295 ],
#        ...,
#        [ 0.005665, ...,  0.001215]]), whiten='arbitrary-variance', fun='cube', random_state=924231285)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# _________________________________________________________fastica - 53.7s, 0.9min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[ 0.003886, ..., -0.00295 ],
#        ...,
#        [ 0.005665, ...,  0.001215]]), whiten='arbitrary-variance', fun='cube', random_state=1478610112)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:  3.7min
# _________________________________________________________fastica - 58.1s, 1.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[ 0.003886, ..., -0.00295 ],
#        ...,
#        [ 0.005665, ...,  0.001215]]), whiten='arbitrary-variance', fun='cube', random_state=441365315)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# _________________________________________________________fastica - 64.4s, 1.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[ 0.003886, ..., -0.00295 ],
#        ...,
#        [ 0.005665, ...,  0.001215]]), whiten='arbitrary-variance', fun='cube', random_state=1537364731)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# _________________________________________________________fastica - 54.0s, 0.9min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[ 0.003886, ..., -0.00295 ],
#        ...,
#        [ 0.005665, ...,  0.001215]]), whiten='arbitrary-variance', fun='cube', random_state=192771779)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# [Parallel(n_jobs=1)]: Done   7 tasks      | elapsed:  6.6min
# _________________________________________________________fastica - 54.3s, 0.9min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[ 0.003886, ..., -0.00295 ],
#        ...,
#        [ 0.005665, ...,  0.001215]]), whiten='arbitrary-variance', fun='cube', random_state=1491434855)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# _________________________________________________________fastica - 53.5s, 0.9min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[ 0.003886, ..., -0.00295 ],
#        ...,
#        [ 0.005665, ...,  0.001215]]), whiten='arbitrary-variance', fun='cube', random_state=1819583497)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# _________________________________________________________fastica - 54.0s, 0.9min
# ________________________________________________________________________________
# [Memory] Calling sklearn.decomposition._fastica.fastica...
# fastica(array([[ 0.003886, ..., -0.00295 ],
#        ...,
#        [ 0.005665, ...,  0.001215]]), whiten='arbitrary-variance', fun='cube', random_state=530702035)
# _________________________________________________________fastica - 54.5s, 0.9min
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/decomposition/_fastica.py:127: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# [CanICA.fit] Computing image from signals

# %% [markdown]
# Plot all ICA components together. All different colors show the regions have similar temporal dynamics
# These maps are also known as "networks", so we identified the "brain networks during movie-watching"!

# %%
plot_prob_atlas(canica_components_img, title="All ICA components", draw_cross=False)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/ma/core.py:2820: UserWarning: Warning: converting a masked element to nan.
#   _data = np.array(data, dtype=dtype, copy=copy,

# %%
# 70% of the variance is explained by these networks. This is good!
# The rest can be missing due to factors such as small sample size,
# inconsistincies in the sample, or noise in the data

print('Total explained variance of the brain activity by the identified networks: ', canica.score(canica.components_img_))
# Out:
# [CanICA.score] Loading data from Nifti1Image('canica_resting_sta...')
# [CanICA.score] Smoothing images
# [CanICA.score] Extracting region signals
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/joblib/memory.py:577: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_masker_extractor'
#   return self._cached_call(args, kwargs, shelving=False)[0]
# [CanICA.score] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.decomposition._base._explained_variance...
# _explained_variance(array([[-6.630991e-01, ...,  4.450777e-01],
#        ...,
#        [-5.064697e-14, ...,  2.837463e-17]]),
# array([[-0., ..., -0.],
#        ...,
#        [-0., ..., -0.]]), per_component=False)
# _______________________________________________explained_variance - 0.5s, 0.0min
# Total explained variance of the brain activity by the identified networks:  0.703387848038309

# %%
# Let's check them one by one 

for i, cur_img in enumerate(iter_img(canica_components_img)):
    plot_stat_map(
        cur_img,
        display_mode="z",
        title=f"IC {int(i)}",
        cut_coords=1,
        colorbar=False,
    )

# %% [markdown]
# ### Okay, they look nice, but what do these maps show?
#
# Now we detected the networks, but we do not know what function or feature they are associated with. Luckily, there is a tool that excels at "decoding" brain maps into their associated structure or functions, called [NeuroSynth](https://neurosynth.org/). It basically utilizes the association between the brain coordinates and cognitive functions reported in (a lot of) previous studes, so it is a kind of meta-search. The tool is capable of doing much more, go ahead and play with it!
#
# In our specific case, we upload those network maps into a NeuroVault [repository](https://neurovault.org/collections/15707/), and then use NeuroSynth's decode function there:
#
# P.s.: There is a nicer way to do the same via python code using neurosynth api and create beatiful wordclouds,  but for some reason it tells me "it is deprecated".

# %%
Image(filename='ica.png')

# %% [markdown]
# ### Now I know what my IC-generated networks mean. How is that useful?
#
# ICA is a common method to detect brain networks and it has high reproducibility. The consistency of the similar networks were shown many times in the literature. Therefore, it is possible to the check the spatial distribution of the specific networks are different in special populations (e.g. visual network in blind people,), or in specific conditions (e.g. attention network during resting vs. during movie watching).

# %% [markdown]
# # PCA
#
# In order to apply PCA on our data, we are going to follow the method in [Marguiles's paper](https://www.pnas.org/doi/10.1073/pnas.1608282113). This method allows decreasing the dimension of the brain signal into a very small number (1-3), and summarize the brain function-structure with nice visualization. However, instead of applying PCA on the data directly (like ICA), this method defines the functionally similar regions first. This helps us to see the regions that are close to each other:

# %%
Image('pca.png')

# %% [markdown]
# The following steps are a combination of the [BrainSpace](https://brainspace.readthedocs.io/en/latest/) ([relevant paper, more methods-rich](https://doi.org/10.1038/s42003-020-0794-7)), [BrainStat](https://brainstat.readthedocs.io/en/master/), and [Micapipe](https://micapipe.readthedocs.io/en/latest/) toolboxes. The procedure described in the Marguiles's paper is applied via BrainSpace, and the other two toolboxes are mostly used for visualization. This method is mostly applied on the "surface space" rather than "voxel space", so the existing toolboxes adopted this tradition. This is why the visuals will be a bit different compared to ICA,

# %%
# Prepare the surface meshes. This code block is for preaparing the upcoming figures

labeling_conte = load_parcellation('schaefer', scale=400, join=True)
c69_lh, c69_rh = load_conte69()


# Load fsaverage5
fs5_lh = read_surface('lh.pial', itype='fs')
fs5_rh = read_surface('rh.pial', itype='fs')


# Load annotation file in fsaverage5
annot_lh_fs5= nb.freesurfer.read_annot('lh.Schaefer2018_400Parcels_7Networks_order.annot')
annot_rh_fs5= nb.freesurfer.read_annot('rh.Schaefer2018_400Parcels_7Networks_order.annot')[0]+200

# replace with 0 the medial wall of the right labels
annot_rh_fs5 = np.where(annot_rh_fs5==200, 0, annot_rh_fs5)

# fsaverage5 labels
labels_fs5 = np.concatenate((annot_lh_fs5[0], annot_rh_fs5), axis=0)

# %% [markdown]
# The data we are going to use is a set of resting-state data from [HCP dataset](https://www.humanconnectome.org/study/hcp-young-adult/data-releases), available in BrainSpace's library. It contains the brain activity during when the subject do not do anything particular, hence measuring natural dynamics of the brain. However, before PCA is applied, the data is already reduced to 400 hundred regions by using the parcellation below. Mean time series within the voxels that corresponding the same regions were extracted, and averaged across subjects:

# %%
yeo_networks = fetch_parcellation("fsaverage5", "yeo", 7)
network_names, yeo_colormap = fetch_yeo_networks_metadata(7)

plot_hemispheres(
    c69_lh,
    c69_rh,
    labeling_conte,
    embed_nb=True,
    cmap="tab20",
    nan_color=(0.7, 0.7, 0.7, 1),
    size=(1400, 200),
    zoom=1.45,
)
# Out:
# 2025-10-23 14:43:26,291 - brainstat - INFO - Downloading /var/folders/j8/ycql35hs3415ybxz7vjtcrr40000gn/T/tmp0kiaqphv.zip from https://box.bic.mni.mcgill.ca/s/vcSXEk1wx0jN86N/download.

# %% [markdown]
# Then, each time series were correlated with each other, creating a 400x400 correlation matrix. As can be seen, some regions have high correlation and already form some clusters that is visible to naked eye:

# %%
conn_matrix = load_group_fc('schaefer', scale=400)
niplot.plot_matrix(conn_matrix, cmap='viridis')

# %% [markdown]
# With the following simple line of code, we are going to calculate the affinity matrix and apply PCA on the thresholded affinity matrix. This will return the 10 principal components, and their eigenvalues (explained variances).

# %%
gm = GradientMaps(n_components=10, approach="pca")
gm.fit(conn_matrix, sparsity=0.8)
# Out:
# GradientMaps(approach='pca')

# %% [markdown]
# In the plot below, you can see the eigenvalues of the components. The first 3 principal components have the highest eigenvalues, hence they explain the most variances in the affinity matrices.

# %%
fig, ax = plt.subplots(1, figsize=(5, 4))
ax.scatter(range(gm.lambdas_.size), gm.lambdas_)
ax.set_xlabel('Component number')
ax.set_ylabel('Eigenvalue')

plt.show()

# %% [markdown]
# Let's look the distribution of the principal component values over regions

# %%
# Mask of the medial wall on fsaverage 5
mask_fs5 = labels_fs5 != 0

 # Map gradients to original parcels
grad = [None] * 3

for i, g in enumerate(gm.gradients_.T[0:3,:]):
     grad[i] = map_to_labels(g, labels_fs5,  fill=np.nan, mask=mask_fs5)

 # Plot Gradients RdYlBu
plot_hemispheres(fs5_lh, fs5_rh, array_name=grad, size=(1000, 600), cmap='brg',
                  embed_nb=True,  label_text={'left':['Grad1', 'Grad2','Grad3']}, color_bar='right',
                  zoom=1.25, nan_color=(1, 1, 1, 1) )

# %% [markdown]
# ### Cool. But what am I looking at?
#
# Let's focus on the first principal component, "Grad1". If you look at the colorbar, you will see that the lowest values are coded with blue, and the highest values are coded with green. The interpretation of this method is that brain function is organized in this "color-axis". Regions that are on the extreme of this distribution are functionally similar to each other, and most of the brain function can be explained by the commonalities of these regions. You can see the distribution of the regions in the 2D space in the following figure:

# %%
plt.scatter(np.array(grad)[0,:],np.array(grad)[1,:],c=(np.array(grad)[0,:]*np.array(grad)[1,:]),cmap='brg')
plt.xlabel('PCA loadings of Gradient 1')
plt.ylabel('PCA loadings of Gradient 2')
# Out:
# Text(0, 0.5, 'PCA loadings of Gradient 2')

# %% [markdown]
# ### What do these "similar regions" correspond to?
#
# We will apply a decoding approach similar to the ICA maps. First, we are going to retrieve a an atlas of 7 functional connectivity network (previously defined by ICA!), and check which which PC loadings correspond to which networks.
#
# The network atlas is displayed below:

# %%
surfaces = fetch_template_surface("fsaverage5", join=False)
yeo_networks = fetch_parcellation("fsaverage5", "yeo", 7)
network_names, yeo_colormap = fetch_yeo_networks_metadata(7)

plot_hemispheres(
    surfaces[0],
    surfaces[1],
    yeo_networks,
    embed_nb=True,
    cmap="yeo7",
    nan_color=(0.7, 0.7, 0.7, 1),
    size=(1400, 200),
    zoom=1.45,
)
# Out:
# Please cite the following papers if you are using this function:
#   [primary]:
#     Anders M Dale, Bruce Fischl, and Martin I Sereno. Cortical surface-based analysis: i. segmentation and surface reconstruction. Neuroimage, 9(2):179–194, 1999.
#     Bruce Fischl, Martin I Sereno, and Anders M Dale. Cortical surface-based analysis: ii: inflation, flattening, and a surface-based coordinate system. Neuroimage, 9(2):195–207, 1999.
#     Bruce Fischl, Martin I Sereno, Roger BH Tootell, and Anders M Dale. High-resolution intersubject averaging and a coordinate system for the cortical surface. Human brain mapping, 8(4):272–284, 1999.
# [fetch_single_file] Downloading data from
# https://files.osf.io/v1/resources/udpv8/providers/osfstorage/67327116b8b930019c62fd6b ...
# [fetch_single_file]  ...done. (10 seconds, 0 min)
# Downloaded tpl-fsaverage to /Users/radek.kawa/brainstat_data/surface_data

# %%
import matplotlib.pyplot as plt
from scipy.stats import sem

from brainstat.context.resting import yeo_networks_associations

yeo_tstat_mean = yeo_networks_associations(grad[0], "fsaverage5")
yeo_tstat_sem = yeo_networks_associations(
    grad[0],
    "fsaverage5",
    reduction_operation=lambda x, y: sem(x, nan_policy="omit"),
)

plt.bar(
    np.arange(7),
    yeo_tstat_mean[:, 0],
    yerr=yeo_tstat_sem.flatten(),
    color=yeo_colormap,
    error_kw={"elinewidth": 5},
)
plt.xticks(np.arange(7), network_names, rotation=90, fontsize=14)
plt.yticks(fontsize=14)
plt.ylabel("PCA loading", fontdict={"fontsize": 16})
plt.gcf().subplots_adjust(left=0.2, bottom=0.5)
plt.show()

# %% [markdown]
# ### What does it mean?
#
# In the above figure, you can see the quantification of the PC scores within the 7 networks we downloaded. As you can see, for the first PC, the visual and somatomotor networks have the highest concentration, and the default/frontoparietal networks have the lowest concentration. This implies that, brain function is mostly organized in the basic functions vs. higher functions axis. regions that are related to those basic cognitive functions are form a cluster, whereas the regions that are related to complex cognitive functions form another one.
#
# Can you edit the code and check the function distribution of the second and third gradients?

# %% [markdown]
# ### Take-home message
#
# Reltively simpler approaches such as ICA and PCA are still very suitable to examine the brain dynamics. They can lead to very complex analysis and are highly reproducible. Identify your needs depending on your hypothesis, and do not unnecessarily complicate your analysis pipeline.
